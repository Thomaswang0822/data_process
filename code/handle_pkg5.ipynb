# %%
"""
This file should handle the raw csv of pkg7 produced by VTD
"""
import pandas as pd
import numpy as np
import csv

# %%
"""
All constants defined here, and we only need to modify here in the future, hopefully.
"""


# A
DATA_DIR = "../0809/2_24/"
SCENE = "2_24"
PKG_ID = '5'
FILE_PATH = DATA_DIR + SCENE + "pkg{}.csv".format(PKG_ID)

OUT_DIR = "../processed0809/"
OUTPUT_PATH = OUT_DIR+SCENE+"pkg{}_del.csv".format(PKG_ID)

# B
# We want playerId and laneId
# which are in col index 2,4
index_to_keep = [2,4,6,7,9]
PATTERN = 12  # number of entries of one road line, which form a pattern
col_of_one = ["playerId", "laneId","roadS", "roadT", "hdgRel"]

PLACE_HOLDER = -99.99

# %%
with open(FILE_PATH, 'r', encoding="utf-8") as csvfile:
    reader = csv.reader(csvfile)
    MAX_LEN = max(len(_) for _ in reader)
    
MAX_LEN
# Out:
# 39

# %%
original_col_names = ["temp.{}".format(i) for i in range(MAX_LEN)]
df5 = pd.read_csv(FILE_PATH, names=original_col_names, low_memory=False)        

df5.drop(index=0, axis=0, inplace=True)
df5.index -= 1
df5.columns = [name.strip() for name in df5.columns]
      
df5.tail(10)
# Out:
#                        temp.0                   temp.1  \
# 5817  +5.8179998699575663e+01                     5819
# 5818  +5.8189998699352145e+01                     5820
# 5819  +5.8199998699128628e+01                     5821
# 5820  +5.8209998698905110e+01                     5822
# 5821  +5.8219998698681593e+01                     5823
# 5822  +5.8229998698458076e+01                     5824
# 5823  +5.8239998698234558e+01                     5825
# 5824  +5.8249998698011041e+01                     5826
# 5825  +5.8259998697787523e+01                     5827
# 5826  +5.8269998697564006e+01                     5828
#
#                        temp.2                   temp.3  \
# 5817                        2                        1
# 5818                        2                        1
# 5819                        2                        1
# 5820                        2                        1
# 5821                        2                        1
# 5822                        2                        1
# 5823                        2                        1
# 5824                        2                        1
# 5825                        2                        1
# 5826                        2                        1
#
#                        temp.4                   temp.5  \
# 5817                       -2                      0x1
# 5818                       -2                      0x1
# 5819                       -2                      0x1
# 5820                       -2                      0x1
# 5821                       -2                      0x1
# 5822                       -2                      0x1
# 5823                       -2                      0x1
# 5824                       -2                      0x1
# 5825                       -2                      0x1
# 5826                       -2                      0x1
#
#                        temp.6                   temp.7  \
# 5817  +3.8837731933593750e+02  -4.7596144676208496e+00
# 5818  +3.8841064453125000e+02  -4.7595658302307129e+00
# 5819  +3.8844396972656250e+02  -4.7595176696777344e+00
# 5820  +3.8847729492187500e+02  -4.7594690322875977e+00
# 5821  +3.8851065063476562e+02  -4.7594203948974609e+00
# 5822  +3.8854397583007812e+02  -4.7593722343444824e+00
# 5823  +3.8857730102539062e+02  -4.7593235969543457e+00
# 5824  +3.8861065673828125e+02  -4.7592754364013672e+00
# 5825  +3.8864398193359375e+02  -4.7592267990112305e+00
# 5826  +3.8867730712890625e+02  -4.7591786384582520e+00
#
#                        temp.8                   temp.9   ...    \
# 5817  -9.7918818937614560e-05  -2.9142168350517750e-03   ...
# 5818  -9.7950556664727628e-05  -2.9129409231245518e-03   ...
# 5819  -9.7982294391840696e-05  -2.9116645455360413e-03   ...
# 5820  -9.8014032118953764e-05  -2.9103877022862434e-03   ...
# 5821  -9.8045769846066833e-05  -2.9091106262058020e-03   ...
# 5822  -9.8077507573179901e-05  -2.9078328516334295e-03   ...
# 5823  -9.8109238024335355e-05  -2.9065548442304134e-03   ...
# 5824  -9.8140983027406037e-05  -2.9052763711661100e-03   ...
# 5825  -9.8172720754519105e-05  -2.9039976652711630e-03   ...
# 5826  -9.8204451205674559e-05  -2.9027182608842850e-03   ...
#
#                       temp.29                  temp.30  \
# 5817                      0x1  +5.0858187866210938e+02
# 5818                      0x1  +5.0871243286132812e+02
# 5819                      0x1  +5.0884301757812500e+02
# 5820                      0x1  +5.0897360229492188e+02
# 5821                      0x1  +5.0910418701171875e+02
# 5822                      0x1  +5.0923477172851562e+02
# 5823                      0x1  +5.0936535644531250e+02
# 5824                      0x1  +5.0949597167968750e+02
# 5825                      0x1  +5.0962661743164062e+02
# 5826                      NaN                      NaN
#
#                       temp.31                  temp.32  \
# 5817  -4.9481515884399414e+00  -1.9815182685852051e-01
# 5818  -4.9480881690979004e+00  -1.9808825850486755e-01
# 5819  -4.9480247497558594e+00  -1.9802488386631012e-01
# 5820  -4.9479618072509766e+00  -1.9796170294284821e-01
# 5821  -4.9478988647460938e+00  -1.9789877533912659e-01
# 5822  -4.9478359222412109e+00  -1.9783610105514526e-01
# 5823  -4.9477739334106445e+00  -1.9777373969554901e-01
# 5824  -4.9477114677429199e+00  -1.9771169126033783e-01
# 5825  -4.9476499557495117e+00  -1.9765000045299530e-01
# 5826                      NaN                      NaN
#
#                       temp.33                  temp.34  \
# 5817  -8.7951129535213113e-04  +1.1347258463501930e-02
# 5818  -8.7899807840585709e-04  +1.1303443461656570e-02
# 5819  -8.7833480210974813e-04  +1.1256837286055088e-02
# 5820  -8.7751547107473016e-04  +1.1208819225430489e-02
# 5821  -8.7653123773634434e-04  +1.1160547845065594e-02
# 5822  -8.7537569925189018e-04  +1.1113030835986137e-02
# 5823  -8.7404053192585707e-04  +1.1067193932831287e-02
# 5824  -8.7251828517764807e-04  +1.1023849248886108e-02
# 5825  -8.7080203229561448e-04  +1.0983677580952644e-02
# 5826                      NaN                      NaN
#
#                       temp.35                  temp.36  \
# 5817  -3.1884897907730192e-05                        0
# 5818  -2.9527947845053859e-05                        0
# 5819  -2.6976116714649834e-05                        0
# 5820  -2.4223578293458559e-05                        0
# 5821  -2.1264668248477392e-05                        0
# 5822  -1.8094220649800263e-05                        0
# 5823  -1.4708230082760565e-05                        0
# 5824  -1.1104370969405863e-05                        0
# 5825  -7.2823490882001352e-06                        0
# 5826                      NaN                      NaN
#
#                       temp.37 temp.38
# 5817  +5.0858187866210938e+02     NaN
# 5818  +5.0871243286132812e+02     NaN
# 5819  +5.0884301757812500e+02     NaN
# 5820  +5.0897360229492188e+02     NaN
# 5821  +5.0910418701171875e+02     NaN
# 5822  +5.0923477172851562e+02     NaN
# 5823  +5.0936535644531250e+02     NaN
# 5824  +5.0949597167968750e+02     NaN
# 5825  +5.0962661743164062e+02     NaN
# 5826                      NaN     NaN
#
# [10 rows x 39 columns]

# %%
rows = df5.shape[0]
num_del = rows%100
df5.drop(labels=range(rows-num_del, rows), axis=0, inplace=True)
df5.shape
# Out:
# (5800, 39)

# %%
"""
Other constants which must be defined after reading in df.


Note: when determing number of objs, we use (#cols-2)/PATTERN.
    But quite often, the raw data has an empty column in the end,
    with pandas automatically giving a name "Unnamed.0"
"""
# C
while (len(df5.columns)-2)%PATTERN != 0:
    # del that col
    print("Found an empty col at the end")
    df5.drop(df5.columns[-1], axis=1, inplace=True)
    
NUM_OBJS = (len(df5.columns)-2)//PATTERN
BEGIN_IDX = NUM_OBJS 
TARGET = 10 # we want 14
END_IDX = 10

# Check if it is a whole number
NUM_OBJS
# Out:
# Found an empty col at the end
# 3

# %%
"""### Keep those cols we want and check ###"""

# a list of column names to delete
cols_to_del = [name for i, name in enumerate(df5.columns) if (i%PATTERN not in index_to_keep and i!=1)]
df5 = df5.drop(columns=cols_to_del)
df5.head(10)
# Out:
#                     temp.1                   temp.2                   temp.4  \
# 0                        2                        2                       -2
# 1                        3                        2                       -2
# 2                        4                        2                       -2
# 3                        5                        2                       -2
# 4                        6                        2                       -2
# 5                        7                        2                       -2
# 6                        8                        2                       -2
# 7                        9                        2                       -2
# 8                       10                        2                       -2
# 9                       11                        2                       -2
#
#                     temp.6                   temp.7                   temp.9  \
# 0  +2.0000000000000000e+02  -5.1696248054504395e+00  -3.6281209904700518e-03
# 1  +2.0000015258789062e+02  -5.1696248054504395e+00  -3.6281298380345106e-03
# 2  +2.0000039672851562e+02  -5.1696243286132812e+00  -3.6281438078731298e-03
# 3  +2.0000074768066406e+02  -5.1696238517761230e+00  -3.6281626671552658e-03
# 4  +2.0000120544433594e+02  -5.1696228981018066e+00  -3.6281859502196312e-03
# 5  +2.0000175476074219e+02  -5.1696219444274902e+00  -3.6282145883888006e-03
# 6  +2.0000239562988281e+02  -5.1696205139160156e+00  -3.6282478831708431e-03
# 7  +2.0000314331054688e+02  -5.1696190834045410e+00  -3.6282860673964024e-03
# 8  +2.0000399780273438e+02  -5.1696176528930664e+00  -3.6283289082348347e-03
# 9  +2.0000494384765625e+02  -5.1696162223815918e+00  -3.6283768713474274e-03
#
#                    temp.14                  temp.16                  temp.18  \
# 0                        3                       -1  +2.5000000000000000e+02
# 1                        3                       -1  +2.5000015258789062e+02
# 2                        3                       -1  +2.5000039672851562e+02
# 3                        3                       -1  +2.5000074768066406e+02
# 4                        3                       -1  +2.5000120544433594e+02
# 5                        3                       -1  +2.5000175476074219e+02
# 6                        3                       -1  +2.5000239562988281e+02
# 7                        3                       -1  +2.5000314331054688e+02
# 8                        3                       -1  +2.5000399780273438e+02
# 9                        3                       -1  +2.5000494384765625e+02
#
#                    temp.19                  temp.21                  temp.26  \
# 0  -1.6567735671997070e+00  -2.3527562152594328e-03                        1
# 1  -1.6567733287811279e+00  -2.3527578450739384e-03                        1
# 2  -1.6567730903625488e+00  -2.3527606390416622e-03                        1
# 3  -1.6567727327346802e+00  -2.3527641315013170e-03                        1
# 4  -1.6567721366882324e+00  -2.3527687881141901e-03                        1
# 5  -1.6567715406417847e+00  -2.3527746088802814e-03                        1
# 6  -1.6567707061767578e+00  -2.3527808953076601e-03                        1
# 7  -1.6567698717117310e+00  -2.3527883458882570e-03                        1
# 8  -1.6567687988281250e+00  -2.3527969606220722e-03                        1
# 9  -1.6567677259445190e+00  -2.3528062738478184e-03                        1
#
#                    temp.28                  temp.30                  temp.31  \
# 0                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 1                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 2                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 3                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 4                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 5                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 6                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 7                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 8                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
# 9                       -2  +1.3032254028320312e+02  -5.1314382553100586e+00
#
#                    temp.33
# 0  -4.8266025260090828e-03
# 1  -4.8266025260090828e-03
# 2  -4.8266025260090828e-03
# 3  -4.8266025260090828e-03
# 4  -4.8266025260090828e-03
# 5  -4.8266025260090828e-03
# 6  -4.8266025260090828e-03
# 7  -4.8266025260090828e-03
# 8  -4.8266025260090828e-03
# 9  -4.8266025260090828e-03

# %%
"""### do some simple pre-process and check ###"""
df5.fillna(PLACE_HOLDER, inplace=True)
df5.rename(columns={"temp.1":"simFrame"}, inplace=True)
df5["simFrame"] = df5["simFrame"].astype(np.int64)
df5.set_index("simFrame", inplace=True)
df5 = df5[~df5.index.duplicated(keep='first')]

new_names = ["{}.{}".format(name,i) for i in range(NUM_OBJS) for name in col_of_one]
df5.columns = new_names


for i in range(NUM_OBJS):
    df5["{}.{}".format(col_of_one[0], i)] = df5["{}.{}".format(col_of_one[0], i)].apply(lambda x: int(x.strip()) if type(x)==str else x)
    print( df5["{}.{}".format(col_of_one[0], i)].value_counts())


# append empty colunms to match designated number of lines reserved: 14
"""
Same work, detail explained in pkg7 file
"""
for i in range(BEGIN_IDX, END_IDX):
    for name in col_of_one:
        df5[name+'.'+str(i)] = PLACE_HOLDER
        
        
NUM_OBJS = END_IDX

print(df5.shape)
df5.head(10)
# Out:
# 2    5800
# Name: playerId.0, dtype: int64
# 3    5800
# Name: playerId.1, dtype: int64
# 1    5800
# Name: playerId.2, dtype: int64
# (5800, 50)
#           playerId.0                 laneId.0                  roadS.0  \
# simFrame
# 2                  2                       -2  +2.0000000000000000e+02
# 3                  2                       -2  +2.0000015258789062e+02
# 4                  2                       -2  +2.0000039672851562e+02
# 5                  2                       -2  +2.0000074768066406e+02
# 6                  2                       -2  +2.0000120544433594e+02
# 7                  2                       -2  +2.0000175476074219e+02
# 8                  2                       -2  +2.0000239562988281e+02
# 9                  2                       -2  +2.0000314331054688e+02
# 10                 2                       -2  +2.0000399780273438e+02
# 11                 2                       -2  +2.0000494384765625e+02
#
#                           roadT.0                 hdgRel.0  playerId.1  \
# simFrame
# 2         -5.1696248054504395e+00  -3.6281209904700518e-03           3
# 3         -5.1696248054504395e+00  -3.6281298380345106e-03           3
# 4         -5.1696243286132812e+00  -3.6281438078731298e-03           3
# 5         -5.1696238517761230e+00  -3.6281626671552658e-03           3
# 6         -5.1696228981018066e+00  -3.6281859502196312e-03           3
# 7         -5.1696219444274902e+00  -3.6282145883888006e-03           3
# 8         -5.1696205139160156e+00  -3.6282478831708431e-03           3
# 9         -5.1696190834045410e+00  -3.6282860673964024e-03           3
# 10        -5.1696176528930664e+00  -3.6283289082348347e-03           3
# 11        -5.1696162223815918e+00  -3.6283768713474274e-03           3
#
#                          laneId.1                  roadS.1  \
# simFrame
# 2                              -1  +2.5000000000000000e+02
# 3                              -1  +2.5000015258789062e+02
# 4                              -1  +2.5000039672851562e+02
# 5                              -1  +2.5000074768066406e+02
# 6                              -1  +2.5000120544433594e+02
# 7                              -1  +2.5000175476074219e+02
# 8                              -1  +2.5000239562988281e+02
# 9                              -1  +2.5000314331054688e+02
# 10                             -1  +2.5000399780273438e+02
# 11                             -1  +2.5000494384765625e+02
#
#                           roadT.1                 hdgRel.1    ...     \
# simFrame                                                      ...
# 2         -1.6567735671997070e+00  -2.3527562152594328e-03    ...
# 3         -1.6567733287811279e+00  -2.3527578450739384e-03    ...
# 4         -1.6567730903625488e+00  -2.3527606390416622e-03    ...
# 5         -1.6567727327346802e+00  -2.3527641315013170e-03    ...
# 6         -1.6567721366882324e+00  -2.3527687881141901e-03    ...
# 7         -1.6567715406417847e+00  -2.3527746088802814e-03    ...
# 8         -1.6567707061767578e+00  -2.3527808953076601e-03    ...
# 9         -1.6567698717117310e+00  -2.3527883458882570e-03    ...
# 10        -1.6567687988281250e+00  -2.3527969606220722e-03    ...
# 11        -1.6567677259445190e+00  -2.3528062738478184e-03    ...
#
#           playerId.8 laneId.8 roadS.8 roadT.8 hdgRel.8  playerId.9  laneId.9  \
# simFrame
# 2             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 3             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 4             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 5             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 6             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 7             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 8             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 9             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 10            -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
# 11            -99.99   -99.99  -99.99  -99.99   -99.99      -99.99    -99.99
#
#           roadS.9  roadT.9  hdgRel.9
# simFrame
# 2          -99.99   -99.99    -99.99
# 3          -99.99   -99.99    -99.99
# 4          -99.99   -99.99    -99.99
# 5          -99.99   -99.99    -99.99
# 6          -99.99   -99.99    -99.99
# 7          -99.99   -99.99    -99.99
# 8          -99.99   -99.99    -99.99
# 9          -99.99   -99.99    -99.99
# 10         -99.99   -99.99    -99.99
# 11         -99.99   -99.99    -99.99
#
# [10 rows x 50 columns]

# %%
"""
MOST important task: Standardization.

Details in handling pkg9 code
    
    
# !!! Take quite a long time
"""
row_nums = df5.shape[0]    # 4760 this time
jump = len(col_of_one)   # 2

for row in range(row_nums):
    old_row = df5.iloc[row]
    new_row = [ [PLACE_HOLDER]*jump ]*NUM_OBJS

    
    # NOTICE: We only have 4 distinct playerId 1-4, but the raw data have 5 chunks
    # Checking raw data, we find there are duplicate chunks
    for idx in range(0, 0 + NUM_OBJS*jump, jump):   # 0, 14, 28, ...
        objId = old_row[idx]
        if objId == PLACE_HOLDER:
            # Special case where id is placeholder -99.99 (also those trailing data)
            continue
        else:
            objId = int(objId)
            # ego car id=1 should go to objectId_0, id=5 should go to objectId=4 likewise.
            new_row[objId] = old_row[idx:idx+jump]
            
    # flat the list
    new_row = [item for sublist in new_row for item in sublist]
    df5.iloc[row] = new_row

              
df5.head(10)
# Out:
#           playerId.0 laneId.0 roadS.0 roadT.0 hdgRel.0  playerId.1  \
# simFrame
# 2             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 3             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 4             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 5             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 6             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 7             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 8             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 9             -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 10            -99.99   -99.99  -99.99  -99.99   -99.99         1.0
# 11            -99.99   -99.99  -99.99  -99.99   -99.99         1.0
#
#                          laneId.1                  roadS.1  \
# simFrame
# 2                              -2  +1.3032254028320312e+02
# 3                              -2  +1.3032254028320312e+02
# 4                              -2  +1.3032254028320312e+02
# 5                              -2  +1.3032254028320312e+02
# 6                              -2  +1.3032254028320312e+02
# 7                              -2  +1.3032254028320312e+02
# 8                              -2  +1.3032254028320312e+02
# 9                              -2  +1.3032254028320312e+02
# 10                             -2  +1.3032254028320312e+02
# 11                             -2  +1.3032254028320312e+02
#
#                           roadT.1                 hdgRel.1   ...     \
# simFrame                                                     ...
# 2         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 3         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 4         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 5         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 6         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 7         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 8         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 9         -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 10        -5.1314382553100586e+00  -4.8266025260090828e-03   ...
# 11        -5.1314382553100586e+00  -4.8266025260090828e-03   ...
#
#           playerId.8 laneId.8 roadS.8 roadT.8 hdgRel.8  playerId.9 laneId.9  \
# simFrame
# 2             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 3             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 4             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 5             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 6             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 7             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 8             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 9             -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 10            -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
# 11            -99.99   -99.99  -99.99  -99.99   -99.99      -99.99   -99.99
#
#          roadS.9 roadT.9 hdgRel.9
# simFrame
# 2         -99.99  -99.99   -99.99
# 3         -99.99  -99.99   -99.99
# 4         -99.99  -99.99   -99.99
# 5         -99.99  -99.99   -99.99
# 6         -99.99  -99.99   -99.99
# 7         -99.99  -99.99   -99.99
# 8         -99.99  -99.99   -99.99
# 9         -99.99  -99.99   -99.99
# 10        -99.99  -99.99   -99.99
# 11        -99.99  -99.99   -99.99
#
# [10 rows x 50 columns]

# %%
# do the check after the sort, there should be no output if it's correct
for i in range(END_IDX):
    assert len(df5["{}.{}".format(col_of_one[0], i)].value_counts()) <= 2, "playerId.{} col still has mixed id, need to further enlarge TARGET {}".format(i, TARGET)

# %%
new_names = ["{}_{}".format(name,i) for i in range(NUM_OBJS) for name in col_of_one]
df5.columns = new_names 
df5.columns
# Out:
# Index(['playerId_0', 'laneId_0', 'roadS_0', 'roadT_0', 'hdgRel_0',
#        'playerId_1', 'laneId_1', 'roadS_1', 'roadT_1', 'hdgRel_1',
#        'playerId_2', 'laneId_2', 'roadS_2', 'roadT_2', 'hdgRel_2',
#        'playerId_3', 'laneId_3', 'roadS_3', 'roadT_3', 'hdgRel_3',
#        'playerId_4', 'laneId_4', 'roadS_4', 'roadT_4', 'hdgRel_4',
#        'playerId_5', 'laneId_5', 'roadS_5', 'roadT_5', 'hdgRel_5',
#        'playerId_6', 'laneId_6', 'roadS_6', 'roadT_6', 'hdgRel_6',
#        'playerId_7', 'laneId_7', 'roadS_7', 'roadT_7', 'hdgRel_7',
#        'playerId_8', 'laneId_8', 'roadS_8', 'roadT_8', 'hdgRel_8',
#        'playerId_9', 'laneId_9', 'roadS_9', 'roadT_9', 'hdgRel_9'],
#       dtype='object')

# %%
df5.to_csv(OUTPUT_PATH)
